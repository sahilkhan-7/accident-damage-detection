# %%
import mysql.connector as connector

# %%
config = {
    'user': 'root',
    'password': 'sahilkhan@7824',
    'host': 'localhost',
    'database': 'car_damage_detection'
}

# %%
def connect_to_db(configuration):
    try:
        connection = connector.connect(**configuration)
    except Exception as e:
        print(f"Can't connect to database, because of {e}")
        
    return connection

# %%
# Car Brands and models with spare parts and their prices
car_models = {
    "AUDI": {
        "A3": {"Bonnet": 300, "Bumper": 200, "Dickey": 250, "Door": 400, "Fender": 150, "Light": 100, "Windshield": 350},
        "A4": {"Bonnet": 320, "Bumper": 210, "Dickey": 260, "Door": 420, "Fender": 160, "Light": 110, "Windshield": 370},
        "A6": {"Bonnet": 340, "Bumper": 220, "Dickey": 270, "Door": 440, "Fender": 170, "Light": 120, "Windshield": 390},
        "Q5": {"Bonnet": 360, "Bumper": 230, "Dickey": 280, "Door": 460, "Fender": 180, "Light": 130, "Windshield": 410},
        "Q7": {"Bonnet": 380, "Bumper": 240, "Dickey": 290, "Door": 480, "Fender": 190, "Light": 140, "Windshield": 430}
    },
    "BMW": {
        "3 Series": {"Bonnet": 320, "Bumper": 210, "Dickey": 260, "Door": 420, "Fender": 160, "Light": 110, "Windshield": 370},
        "5 Series": {"Bonnet": 340, "Bumper": 220, "Dickey": 270, "Door": 440, "Fender": 170, "Light": 120, "Windshield": 390},
        "7 Series": {"Bonnet": 360, "Bumper": 230, "Dickey": 280, "Door": 460, "Fender": 180, "Light": 130, "Windshield": 410},
        "X3": {"Bonnet": 380, "Bumper": 240, "Dickey": 290, "Door": 480, "Fender": 190, "Light": 140, "Windshield": 430},
        "X5": {"Bonnet": 400, "Bumper": 250, "Dickey": 300, "Door": 500, "Fender": 200, "Light": 150, "Windshield": 450}
    },
    "DATSUN": {
        "Go": {"Bonnet": 150, "Bumper": 100, "Dickey": 120, "Door": 200, "Fender": 80, "Light": 50, "Windshield": 180},
        "Go+": {"Bonnet": 160, "Bumper": 110, "Dickey": 130, "Door": 220, "Fender": 90, "Light": 60, "Windshield": 190},
        "Redi-Go": {"Bonnet": 170, "Bumper": 120, "Dickey": 140, "Door": 240, "Fender": 100, "Light": 70, "Windshield": 200}
    },
    "FORD": {
        "Mustang": {"Bonnet": 400, "Bumper": 250, "Dickey": 300, "Door": 500, "Fender": 200, "Light": 150, "Windshield": 450},
        "Focus": {"Bonnet": 420, "Bumper": 260, "Dickey": 310, "Door": 520, "Fender": 220, "Light": 170, "Windshield": 470},
        "Fusion": {"Bonnet": 440, "Bumper": 270, "Dickey": 320, "Door": 540, "Fender": 240, "Light": 190, "Windshield": 490},
        "Explorer": {"Bonnet": 460, "Bumper": 280, "Dickey": 330, "Door": 560, "Fender": 260, "Light": 210, "Windshield": 510},
        "F-150": {"Bonnet": 480, "Bumper": 290, "Dickey": 340, "Door": 580, "Fender": 280, "Light": 230, "Windshield": 530}
    },
    "HONDA": {
        "Civic": {"Bonnet": 350, "Bumper": 230, "Dickey": 280, "Door": 450, "Fender": 180, "Light": 130, "Windshield": 400},
        "Accord": {"Bonnet": 370, "Bumper": 240, "Dickey": 290, "Door": 470, "Fender": 190, "Light": 140, "Windshield": 420},
        "CR-V": {"Bonnet": 390, "Bumper": 250, "Dickey": 300, "Door": 490, "Fender": 200, "Light": 150, "Windshield": 440},
        "Pilot": {"Bonnet": 410, "Bumper": 260, "Dickey": 310, "Door": 510, "Fender": 210, "Light": 160, "Windshield": 460},
        "HR-V": {"Bonnet": 430, "Bumper": 270, "Dickey": 320, "Door": 530, "Fender": 220, "Light": 170, "Windshield": 480}
    },
    "HYUNDAI": {
        "Sonata": {"Bonnet": 330, "Bumper": 220, "Dickey": 270, "Door": 430, "Fender": 170, "Light": 120, "Windshield": 380},
        "Elantra": {"Bonnet": 350, "Bumper": 230, "Dickey": 280, "Door": 450, "Fender": 180, "Light": 130, "Windshield": 400},
        "Tucson": {"Bonnet": 370, "Bumper": 240, "Dickey": 290, "Door": 470, "Fender": 190, "Light": 140, "Windshield": 420},
        "Santa Fe": {"Bonnet": 390, "Bumper": 250, "Dickey": 300, "Door": 490, "Fender": 200, "Light": 150, "Windshield": 440},
        "Kona": {"Bonnet": 410, "Bumper": 260, "Dickey": 310, "Door": 510, "Fender": 210, "Light": 160, "Windshield": 460}
    },
    "JEEP": {
        "Wrangler": {"Bonnet": 400, "Bumper": 300, "Dickey": 350, "Door": 500, "Fender": 250, "Light": 200, "Windshield": 450},
        "Grand Cherokee": {"Bonnet": 420, "Bumper": 320, "Dickey": 370, "Door": 520, "Fender": 270, "Light": 220, "Windshield": 470},
        "Cherokee": {"Bonnet": 380, "Bumper": 280, "Dickey": 330, "Door": 480, "Fender": 230, "Light": 180, "Windshield": 430},
        "Renegade": {"Bonnet": 360, "Bumper": 260, "Dickey": 310, "Door": 460, "Fender": 210, "Light": 160, "Windshield": 410},
        "Compass": {"Bonnet": 340, "Bumper": 240, "Dickey": 290, "Door": 440, "Fender": 190, "Light": 140, "Windshield": 390},
    },
    "KIA": {
        "Optima": {"Bonnet": 380, "Bumper": 280, "Dickey": 330, "Door": 480, "Fender": 230, "Light": 180, "Windshield": 430},
        "Soul": {"Bonnet": 360, "Bumper": 260, "Dickey": 310, "Door": 460, "Fender": 210, "Light": 160, "Windshield": 410},
        "Sorento": {"Bonnet": 380, "Bumper": 280, "Dickey": 330, "Door": 480, "Fender": 230, "Light": 180, "Windshield": 430},
        "Sportage": {"Bonnet": 360, "Bumper": 260, "Dickey": 310, "Door": 460, "Fender": 210, "Light": 160, "Windshield": 410},
        "Telluride": {"Bonnet": 400, "Bumper": 300, "Dickey": 350, "Door": 500, "Fender": 250, "Light": 200, "Windshield": 450},
    },
    "MAHINDRA": {
        "Scorpio": {"Bonnet": 350, "Bumper": 250, "Dickey": 300, "Door": 450, "Fender": 200, "Light": 150, "Windshield": 400},
        "XUV500": {"Bonnet": 370, "Bumper": 270, "Dickey": 320, "Door": 470, "Fender": 220, "Light": 170, "Windshield": 420},
        "Thar": {"Bonnet": 360, "Bumper": 260, "Dickey": 310, "Door": 460, "Fender": 210, "Light": 160, "Windshield": 410},
        "Bolero": {"Bonnet": 340, "Bumper": 240, "Dickey": 290, "Door": 440, "Fender": 190, "Light": 140, "Windshield": 390},
        "Marazzo": {"Bonnet": 380, "Bumper": 280, "Dickey": 330, "Door": 480, "Fender": 230, "Light": 180, "Windshield": 430},
    },
    "MARUTI": {
        "Swift": {"Bonnet": 300, "Bumper": 200, "Dickey": 250, "Door": 400, "Fender": 150, "Light": 100, "Windshield": 350},
        "Alto": {"Bonnet": 320, "Bumper": 220, "Dickey": 270, "Door": 420, "Fender": 160, "Light": 110, "Windshield": 370},
        "Baleno": {"Bonnet": 340, "Bumper": 240, "Dickey": 290, "Door": 440, "Fender": 170, "Light": 120, "Windshield": 390},
        "Vitara Brezza": {"Bonnet": 360, "Bumper": 260, "Dickey": 310, "Door": 460, "Fender": 180, "Light": 130, "Windshield": 410},
        "Wagon R": {"Bonnet": 380, "Bumper": 280, "Dickey": 330, "Door": 480, "Fender": 190, "Light": 140, "Windshield": 430},
    },
    "NISSAN": {
        "Altima": {"Bonnet": 350, "Bumper": 250, "Dickey": 300, "Door": 450, "Fender": 200, "Light": 150, "Windshield": 400},
        "Rogue": {"Bonnet": 370, "Bumper": 270, "Dickey": 320, "Door": 470, "Fender": 220, "Light": 170, "Windshield": 420},
        "Sentra": {"Bonnet": 340, "Bumper": 240, "Dickey": 290, "Door": 440, "Fender": 190, "Light": 140, "Windshield": 390},
        "Pathfinder": {"Bonnet": 360, "Bumper": 260, "Dickey": 310, "Door": 460, "Fender": 210, "Light": 160, "Windshield": 410},
        "Titan": {"Bonnet": 380, "Bumper": 280, "Dickey": 330, "Door": 480, "Fender": 230, "Light": 180, "Windshield": 430},
    },
    "SKODA": {
        "Octavia": {"Bonnet": 370, "Bumper": 270, "Dickey": 320, "Door": 470, "Fender": 220, "Light": 170, "Windshield": 420},
        "Superb": {"Bonnet": 390, "Bumper": 290, "Dickey": 340, "Door": 490, "Fender": 240, "Light": 190, "Windshield": 440},
        "Rapid": {"Bonnet": 350, "Bumper": 250, "Dickey": 300, "Door": 450, "Fender": 200, "Light": 150, "Windshield": 400},
        "Kodiaq": {"Bonnet": 400, "Bumper": 300, "Dickey": 350, "Door": 500, "Fender": 250, "Light": 200, "Windshield": 450},
        "Karoq": {"Bonnet": 360, "Bumper": 260, "Dickey": 310, "Door": 460, "Fender": 210, "Light": 160, "Windshield": 410},
    },
    "TATA": {
        "Tiago": {"Bonnet": 340, "Bumper": 240, "Dickey": 290, "Door": 440, "Fender": 190, "Light": 140, "Windshield": 390},
        "Nexon": {"Bonnet": 360, "Bumper": 260, "Dickey": 310, "Door": 460, "Fender": 210, "Light": 160, "Windshield": 410},
        "Harrier": {"Bonnet": 380, "Bumper": 280, "Dickey": 330, "Door": 480, "Fender": 230, "Light": 180, "Windshield": 430},
        "Safari": {"Bonnet": 370, "Bumper": 270, "Dickey": 320, "Door": 470, "Fender": 220, "Light": 170, "Windshield": 420},
        "Altroz": {"Bonnet": 350, "Bumper": 250, "Dickey": 300, "Door": 450, "Fender": 200, "Light": 150, "Windshield": 400},
    },
    "TOYOTA": {
        "Camry": {"Bonnet": 400, "Bumper": 300, "Dickey": 350, "Door": 500, "Fender": 250, "Light": 200, "Windshield": 450},
        "Corolla": {"Bonnet": 380, "Bumper": 280, "Dickey": 330, "Door": 480, "Fender": 230, "Light": 180, "Windshield": 430},
        "RAV4": {"Bonnet": 420, "Bumper": 320, "Dickey": 370, "Door": 520, "Fender": 270, "Light": 220, "Windshield": 470},
        "Highlander": {"Bonnet": 410, "Bumper": 310, "Dickey": 360, "Door": 510, "Fender": 260, "Light": 210, "Windshield": 460},
        "Tacoma": {"Bonnet": 390, "Bumper": 290, "Dickey": 340, "Door": 490, "Fender": 240, "Light": 190, "Windshield": 440},
    },
    "VOLVO": {
        "XC90": {"Bonnet": 430, "Bumper": 330, "Dickey": 380, "Door": 530, "Fender": 280, "Light": 230, "Windshield": 480},
        "XC60": {"Bonnet": 410, "Bumper": 310, "Dickey": 360, "Door": 510, "Fender": 260, "Light": 210, "Windshield": 460},
        "S60": {"Bonnet": 390, "Bumper": 290, "Dickey": 340, "Door": 490, "Fender": 240, "Light": 190, "Windshield": 440},
        "V60": {"Bonnet": 400, "Bumper": 300, "Dickey": 350, "Door": 500, "Fender": 250, "Light": 200, "Windshield": 450},
        "S90": {"Bonnet": 420, "Bumper": 320, "Dickey": 370, "Door": 520, "Fender": 270, "Light": 220, "Windshield": 470},
    },
}

# %%
# Adding data into Car_info

connection = connect_to_db(config)
cursor = connection.cursor()

# Loop through car_models dictionary and insert data into database
for brand, models in car_models.items():
    for model, parts in models.items():
        for part, price in parts.items():
            cursor.execute("INSERT INTO car_models (brand, model, part, price) VALUES (%s, %s, %s, %s)",
                           (brand, model, part, price))

# Commit changes and close connection
connection.commit()
connection.close()

print("Data has been successfully inserted into the MySQL database.")
# Out:
# Data has been successfully inserted into the MySQL database.
